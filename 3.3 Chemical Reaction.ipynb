# %%
c1 = [50.0]
c2 = [25.0]
c3 = [0.0]
kl = 0.025
k2 = 0.01
time_difference = 0.1
t = 0.0
last_time = 15.0
i = 0
print("\nTime  \tC1    \tC2    C3")

while t <= last_time:
    print(f"{t:.2f} \t{c1[i]:.2f} \t{c2[i]:.2f} \t{c3[i]:.2f}")

    c1_next = c1[i] + (k2 * c3[i] - kl * c1[i] * c2[i]) * time_difference
    c2_next = c2[i] + (k2 * c3[i] - kl * c1[i] * c2[i]) * time_difference
    c3_next = c3[i] + 2.0 * (kl * c1[i] * c2[i] - k2 * c3[i]) * time_difference

    c1.append(c1_next)
    c2.append(c2_next)
    c3.append(c3_next)

    i += 1
    t += time_difference

    if t >= 2.0:
        time_difference = 0.2
    if t == 6.0:
        time_difference = 0.4
# Out:
# Time  	C1    	C2    C3
# 0.00 	50.00 	25.00 	0.00
# 0.10 	46.88 	21.88 	6.25
# 0.20 	44.32 	19.32 	11.36
# 0.30 	42.19 	17.19 	15.62
# 0.40 	40.39 	15.39 	19.22
# 0.50 	38.86 	13.86 	22.29
# 0.60 	37.53 	12.53 	24.93
# 0.70 	36.38 	11.38 	27.24
# 0.80 	35.37 	10.37 	29.25
# 0.90 	34.49 	9.49 	31.03
# 1.00 	33.70 	8.70 	32.60
# 1.10 	33.00 	8.00 	34.00
# 1.20 	32.37 	7.37 	35.25
# 1.30 	31.81 	6.81 	36.38
# 1.40 	31.31 	6.31 	37.39
# 1.50 	30.85 	5.85 	38.30
# 1.60 	30.44 	5.44 	39.13
# 1.70 	30.06 	5.06 	39.88
# 1.80 	29.72 	4.72 	40.56
# 1.90 	29.41 	4.41 	41.18
# 2.00 	29.13 	4.13 	41.74
# 2.20 	28.61 	3.61 	42.78
# 2.40 	28.18 	3.18 	43.64
# 2.60 	27.82 	2.82 	44.36
# 2.80 	27.52 	2.52 	44.97
# 3.00 	27.26 	2.26 	45.48
# 3.20 	27.04 	2.04 	45.92
# 3.40 	26.86 	1.86 	46.28
# 3.60 	26.70 	1.70 	46.60
# 3.80 	26.57 	1.57 	46.87
# 4.00 	26.45 	1.45 	47.09
# 4.20 	26.35 	1.35 	47.29
# 4.40 	26.27 	1.27 	47.46
# 4.60 	26.20 	1.20 	47.60
# 4.80 	26.14 	1.14 	47.73
# 5.00 	26.08 	1.08 	47.83
# 5.20 	26.04 	1.04 	47.92
# 5.40 	26.00 	1.00 	48.00
# 5.60 	25.97 	0.97 	48.07
# 5.80 	25.94 	0.94 	48.13
# 6.00 	25.91 	0.91 	48.18
# 6.20 	25.89 	0.89 	48.22
# 6.40 	25.87 	0.87 	48.26
# 6.60 	25.85 	0.85 	48.29
# 6.80 	25.84 	0.84 	48.32
# 7.00 	25.83 	0.83 	48.34
# 7.20 	25.82 	0.82 	48.36
# 7.40 	25.81 	0.81 	48.38
# 7.60 	25.80 	0.80 	48.40
# 7.80 	25.80 	0.80 	48.41
# 8.00 	25.79 	0.79 	48.42
# 8.20 	25.78 	0.78 	48.43
# 8.40 	25.78 	0.78 	48.44
# 8.60 	25.78 	0.78 	48.45
# 8.80 	25.77 	0.77 	48.45
# 9.00 	25.77 	0.77 	48.46
# 9.20 	25.77 	0.77 	48.46
# 9.40 	25.77 	0.77 	48.47
# 9.60 	25.76 	0.76 	48.47
# 9.80 	25.76 	0.76 	48.47
# 10.00 	25.76 	0.76 	48.48
# 10.20 	25.76 	0.76 	48.48
# 10.40 	25.76 	0.76 	48.48
# 10.60 	25.76 	0.76 	48.48
# 10.80 	25.76 	0.76 	48.48
# 11.00 	25.76 	0.76 	48.49
# 11.20 	25.76 	0.76 	48.49
# 11.40 	25.76 	0.76 	48.49
# 11.60 	25.76 	0.76 	48.49
# 11.80 	25.76 	0.76 	48.49
# 12.00 	25.76 	0.76 	48.49
# 12.20 	25.75 	0.75 	48.49
# 12.40 	25.75 	0.75 	48.49
# 12.60 	25.75 	0.75 	48.49
# 12.80 	25.75 	0.75 	48.49
# 13.00 	25.75 	0.75 	48.49
# 13.20 	25.75 	0.75 	48.49
# 13.40 	25.75 	0.75 	48.49
# 13.60 	25.75 	0.75 	48.49
# 13.80 	25.75 	0.75 	48.49
# 14.00 	25.75 	0.75 	48.49
# 14.20 	25.75 	0.75 	48.49
# 14.40 	25.75 	0.75 	48.49
# 14.60 	25.75 	0.75 	48.49
# 14.80 	25.75 	0.75 	48.49
# 15.00 	25.75 	0.75 	48.49
